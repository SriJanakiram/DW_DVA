# %% [markdown]
# # Using Jupyter Notebooks
# :label:`sec_jupyter`
#
#
# This section describes how to edit and run the code
# in each section of this book
# using the Jupyter Notebook. Make sure you have
# installed Jupyter and downloaded the
# code as described in
# :ref:`chap_installation`.
# If you want to know more about Jupyter see the excellent tutorial in
# their [documentation](https://jupyter.readthedocs.io/en/latest/).
#
#
# ## Editing and Running the Code Locally
#
# Suppose that the local path of the book's code is `xx/yy/d2l-en/`. Use the shell to change the directory to this path (`cd xx/yy/d2l-en`) and run the command `jupyter notebook`. If your browser does not do this automatically, open http://localhost:8888 and you will see the interface of Jupyter and all the folders containing the code of the book, as shown in :numref:`fig_jupyter00`.
#
# ![The folders containing the code of this book.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter00.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter00`
#
#
# You can access the notebook files by clicking on the folder displayed on the webpage.
# They usually have the suffix ".ipynb".
# For the sake of brevity, we create a temporary "test.ipynb" file.
# The content displayed after you click it is
# shown in :numref:`fig_jupyter01`.
# This notebook includes a markdown cell and a code cell. The content in the markdown cell includes "This Is a Title" and "This is text.".
# The code cell contains two lines of Python code.
#
# ![Markdown and code cells in the "text.ipynb" file.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter01.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter01`
#
#
# Double click on the markdown cell to enter edit mode.
# Add a new text string "Hello world." at the end of the cell, as shown in :numref:`fig_jupyter02`.
#
# ![Edit the markdown cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter02.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter02`
#
#
# As demonstrated in :numref:`fig_jupyter03`,
# click "Cell" $\rightarrow$ "Run Cells" in the menu bar to run the edited cell.
#
# ![Run the cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter03.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter03`
#
# After running, the markdown cell is shown in :numref:`fig_jupyter04`.
#
# ![The markdown cell after running.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter04.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter04`
#
#
# Next, click on the code cell. Multiply the elements by 2 after the last line of code, as shown in :numref:`fig_jupyter05`.
#
# ![Edit the code cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter05.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter05`
#
#
# You can also run the cell with a shortcut ("Ctrl + Enter" by default) and obtain the output result from :numref:`fig_jupyter06`.
#
# ![Run the code cell to obtain the output.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter06.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter06`
#
#
# When a notebook contains more cells, we can click "Kernel" $\rightarrow$ "Restart & Run All" in the menu bar to run all the cells in the entire notebook. By clicking "Help" $\rightarrow$ "Edit Keyboard Shortcuts" in the menu bar, you can edit the shortcuts according to your preferences.
#
# ## Advanced Options
#
# Beyond local editing two things are quite important: editing the notebooks in the markdown format and running Jupyter remotely.
# The latter matters when we want to run the code on a faster server.
# The former matters since Jupyter's native ipynb format stores a lot of auxiliary data that is
# irrelevant to the content,
# mostly related to how and where the code is run.
# This is confusing for Git, making
# reviewing contributions very difficult.
# Fortunately there is an alternative---native editing in the markdown format.
#
# ### Markdown Files in Jupyter
#
# If you wish to contribute to the content of this book, you need to modify the
# source file (md file, not ipynb file) on GitHub.
# Using the notedown plugin we
# can modify notebooks in the md format directly in Jupyter.
#
#
# First, install the notedown plugin, run the Jupyter Notebook, and load the plugin:
#
# ```
# pip install d2l-notedown  # You may need to uninstall the original notedown.
# jupyter notebook --NotebookApp.contents_manager_class='notedown.NotedownContentsManager'
# ```
#
# You may also turn on the notedown plugin by default whenever you run the Jupyter Notebook.
# First, generate a Jupyter Notebook configuration file (if it has already been generated, you can skip this step).
#
# ```
# jupyter notebook --generate-config
# ```
#
# Then, add the following line to the end of the Jupyter Notebook configuration file (for Linux or macOS, usually in the path `~/.jupyter/jupyter_notebook_config.py`):
#
# ```
# c.NotebookApp.contents_manager_class = 'notedown.NotedownContentsManager'
# ```
#
# After that, you only need to run the `jupyter notebook` command to turn on the notedown plugin by default.
#
# ### Running Jupyter Notebooks on a Remote Server
#
# Sometimes, you may want to run Jupyter notebooks on a remote server and access it through a browser on your local computer. If Linux or macOS is installed on your local machine (Windows can also support this function through third-party software such as PuTTY), you can use port forwarding:
#
# ```
# ssh myserver -L 8888:localhost:8888
# ```
#
# The above string `myserver` is the address of the remote server.
# Then we can use http://localhost:8888 to access the remote server `myserver` that runs Jupyter notebooks. We will detail on how to run Jupyter notebooks on AWS instances
# later in this appendix.
#
# ### Timing
#
# We can use the `ExecuteTime` plugin to time the execution of each code cell in Jupyter notebooks.
# Use the following commands to install the plugin:
#
# ```
# pip install jupyter_contrib_nbextensions
# jupyter contrib nbextension install --user
# jupyter nbextension enable execute_time/ExecuteTime
# ```
#
# ## Summary
#
# * Using the Jupyter Notebook tool, we can edit, run, and contribute to each section of the book.
# * We can run Jupyter notebooks on remote servers using port forwarding.
#
#
# ## Exercises
#
# 1. Edit and run the code in this book with the Jupyter Notebook on your local machine.
# 1. Edit and run the code in this book with the Jupyter Notebook *remotely* via port forwarding.
# 1. Compare the running time of the operations $\mathbf{A}^\top \mathbf{B}$ and $\mathbf{A} \mathbf{B}$ for two square matrices in $\mathbb{R}^{1024 \times 1024}$. Which one is faster?
#
#
# [Discussions](https://discuss.d2l.ai/t/421)

# %%
c
# Out:
# Enter the categories separated by commas: phy,che,mat
# Enter the corresponding values separated by commas: 20,50,80
# Enter x-axis label: name of subject
# Enter y-axis label: marks obtained
# Enter the title for the plot: marks in each subject

# %%
import matplotlib.pyplot as plt
x = input("Enter the categories separated by commas: ").split(',')
y = list(map(int, input("Enter the corresponding values separated by commas: ").split(',')))
xlabel = input("Enter x-axis label: ")
ylabel = input("Enter y-axis label: ")
title = input("Enter the title for the plot: ")
plt.barh(x, y)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.show()
# Out:
# Enter the categories separated by commas: phy,che,mat
# Enter the corresponding values separated by commas: 20,50,80
# Enter x-axis label: marks obtained
# Enter y-axis label: name of subject
# Enter the title for the plot: marks in each subject

# %%
import matplotlib.pyplot as plt
import numpy as np
x = input("Enter the categories separated by commas: ").split(',')
y1 = list(map(int, input("Enter the values for y1 separated by commas: ").split(',')))
y2 = list(map(int, input("Enter the values for y2 separated by commas: ").split(',')))
x = np.array(x)
y1 = np.array(y1)
y2 = np.array(y2)
plt.bar(x, y1, color='r')
plt.bar(x, y2, bottom=y1, color='b')
plt.show()
# Out:
# Enter the categories separated by commas: A,B,C,D
# Enter the values for y1 separated by commas: 10,20,40,30
# Enter the values for y2 separated by commas: 20,30,5,6

# %%
import matplotlib.pyplot as plt
import numpy as np
x = input("Enter the categories separated by commas: ").split(',')
y1 = list(map(int, input("Enter the values for y1 separated by commas: ").split(',')))
y2 = list(map(int, input("Enter the values for y2 separated by commas: ").split(',')))
x = np.array(x)
y1 = np.array(y1)
y2 = np.array(y2)
plt.barh(x, y1, color='r')
plt.barh(x, y2, left=y1, color='b')
plt.show()
# Out:
# Enter the categories separated by commas: A,B,C,D
# Enter the values for y1 separated by commas: 10,20,40,30
# Enter the values for y2 separated by commas: 20,30,5,6

# %%
import matplotlib.pyplot as plt
import numpy as np
x = input("Enter the categories separated by commas: ").split(',')
y1 = list(map(int, input("Enter the values for y1 separated by commas: ").split(',')))
y2 = list(map(int, input("Enter the values for y2 separated by commas: ").split(',')))
x = np.array(x)
x_indices = np.arange(len(x))
print(x_indices)
bar_width = 0.35
plt.bar(x_indices - bar_width / 2, y1, width=bar_width, color='r', label='Group 1')
plt.bar(x_indices + bar_width / 2, y2, width=bar_width, color='b', label='Group 2')
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Grouped Bar Plot")
plt.xticks(x_indices, x)
plt.legend()
plt.show()
# Out:
# Enter the categories separated by commas: A,B,C,D
# Enter the values for y1 separated by commas: 10,20,40,30
# Enter the values for y2 separated by commas: 20,3,5,6
# [0 1 2 3]

# %%
import matplotlib.pyplot as plt
import numpy as np
x = input("Enter the categories separated by commas: ").split(',')
y1 = list(map(int, input("Enter the values for y1 separated by commas: ").split(',')))
y2 = list(map(int, input("Enter the values for y2 separated by commas: ").split(',')))
x = np.array(x)
x_indices = np.arange(len(x))
bar_height = 0.35
plt.barh(x_indices - bar_height / 2, y1, height=bar_height, color='r', label='Group 1')
plt.barh(x_indices + bar_height / 2, y2, height=bar_height, color='b', label='Group 2')
plt.ylabel("Categories")
plt.xlabel("Values")
plt.title("Grouped Horizontal Bar Plot")
plt.yticks(x_indices, x)
plt.legend()
plt.show()
# Out:
# Enter the categories separated by commas: A,B,C,D
# Enter the values for y1 separated by commas: 10,20,40,30
# Enter the values for y2 separated by commas: 20,30,5,6

# %%
import numpy as np
data=np.random.randn(1000)
plt.hist(data,bins=30,color='skyblue',edgecolor='black')
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('vertical histogram')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.randn(1000)
plt.hist(data, bins=30, color='skyblue', edgecolor='black', orientation='horizontal')
plt.ylabel('Values')
plt.xlabel('Frequency')
plt.title('Basic Horizontal Histogram')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data1 = np.random.randn(1000)
data2 = np.random.randn(700)
plt.hist(data1, bins=30, color='red', edgecolor='black', alpha=0.6, label='Data 1')
plt.hist(data2, bins=20, color='blue', edgecolor='black', alpha=0.6, label='Data 2')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Overlapping Histograms')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data1 = np.random.randn(1000)
data2 = np.random.randn(700)
plt.hist(data1, bins=30, color='red', edgecolor='black', alpha=0.6, label='Data 1',orientation='horizontal')
plt.hist(data2, bins=20, color='blue', edgecolor='black', alpha=0.6, label='Data 2',orientation='horizontal')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Overlapping Histograms')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data1 = np.random.randn(1000)
data2 = np.random.randn(700)
data = [data1, data2]
plt.hist(data, bins=30, color=['red', 'blue'], edgecolor='black', alpha=0.6, label=['Data 1', 'Data 2'], orientation='vertical', stacked=True)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Stacked Histograms')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
data1 = np.random.randn(1000)
data2 = np.random.randn(700)
data=[data1,data2]
plt.hist(data,bins=30,color=['red','blue'],edgecolor='black',alpha=0.6,label=['label 1','label 2'],orientation='horizontal',stacked=True)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Stacked Histograms')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = input("Enter the categories separated by commas: ").split(',')
y1 = list(map(int, input("Enter the values for y1 separated by commas: ").split(',')))
x = np.array(x)
y1 = np.array(y1)
plt.plot(y1, x, 'o',color='r')
plt.xlabel('Values')
plt.title('Dot Plot')
plt.show()
# Out:
# Enter the categories separated by commas: A,B,C,D
# Enter the values for y1 separated by commas: 1,2,3,4

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
data = np.random.randint(low = 1, high = 100, size = (10, 10))
print("The data to be plotted:\n")
print(data)
hm = sn.heatmap(data = data)
plt.show()
# Out:
# The data to be plotted:
#
# [[ 1 84  6 97 70 19  5 36 64 58]
#  [80 23 77 66 34 23 23 33 29 18]
#  [47 50 92 87 69 12 98 94 61 52]
#  [47 88 98 64 11 57 72 69 13 54]
#  [27 97 17 31 82 65 81 52 29 86]
#  [96 85 29 42 63 90 85 37 75 25]
#  [85 85 90 69  5 71 17  7 42 71]
#  [14 59 30 24 82 44 31 64 58 14]
#  [45 70 45 84 16 50 47 86 67 24]
#  [46 88 27 60 72 36 72 20 45 10]]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("the data to be plotted:\n")
print(data)
hm=sns.heatmap(data=data)
plt.show()
# Out:
# the data to be plotted:
#
# [[23 44  8 71 51 35 72 24 27 99]
#  [68 30 66 96 12 15 90 26 15 57]
#  [85 14 34 98 24 81 59 97 24 20]
#  [87 73  7 22 10 42 73 80 10 55]
#  [84 66 10 91 50 79 75 43  7 43]
#  [ 2 51 83 32 86  3 37 19  4 57]
#  [46 81 83 84 44 37 47  6 24 97]
#  [ 1 99 71 48 41 35 37 19 34 74]
#  [ 4 41  6 82  8 62 17 27 36 19]
#  [51 86 96 88 57 82  7 47 87 71]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = list(map(float, input("Enter a list of numerical data separated by spaces: ").split()))
sns.set()
sns.kdeplot(data,color='blue',fill=True)
plt.show()
# Out:
# Enter a list of numerical data separated by spaces: 1 2 4 5 3 2 2 4 6 4 4 45 3 2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data1 = list(map(float, input("Enter a list of numerical data1 separated by spaces: ").split()))
data2 = list(map(float, input("Enter a list of numerical data2 separated by spaces: ").split()))
sns.set()
sns.kdeplot(data1,color='blue',fill=True,alpha=0.5,label='data1')
sns.kdeplot(data2,color='red',fill=True,alpha=0.5,label='data2')
plt.show()
# Out:
# Enter a list of numerical data1 separated by spaces: 1 3 5 7 9
# Enter a list of numerical data2 separated by spaces: 2 4 6 8 10

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = list(map(float, input("Enter list of values separated by spaces: ").split()))
sns.ecdfplot(data)
plt.xlabel('Data points')
plt.ylabel('ECDF')
plt.title('Empirical Cumulative Distribution Function (ECDF)')
plt.show()
# Out:
# Enter list of values separated by spaces: 5 10 15 20 25 30 35 40 45 50

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
n = int(input("Enter number of items: "))
data = np.random.normal(loc=0, scale=1, size=n)
sm.qqplot(data, line ='45')
plt.title("Q-Q Plot")
plt.show()
# Out:
# Enter number of items: 50

# %%
import matplotlib.pyplot as plt
temp_data = list(map(float, input("Enter temperatures separated by spaces: ").split()))
plt.boxplot(temp_data)
plt.xlabel("Temperature Distribution")
plt.ylabel("Degrees Celsius")
plt.title("Box Plot of Temperature Data")
plt.show()
# Out:
# Enter temperatures separated by spaces: 30 120 150 45 80 90 39 29

# %%
import matplotlib.pyplot as plt
n = int(input("Enter number of temperature datasets: "))
temp_data = []
for i in range(n):
    temperatures = list(map(float, input(f"Enter temperatures for dataset {i+1} separated by spaces: ").split()))
    temp_data.append(temperatures)
plt.boxplot(temp_data)
plt.xlabel("Dataset")
plt.ylabel("Degrees Celsius")
plt.title("Box Plot of Temperature Data")
plt.show()
# Out:
# Enter number of temperature datasets: 2
# Enter temperatures for dataset 1 separated by spaces: 12 36 60
# Enter temperatures for dataset 2 separated by spaces: 13 39 75

# %%
import matplotlib.pyplot as plt
import numpy as np
x = list(map(float, input("Enter x values separated by spaces: ").split()))
y = list(map(float, input("Enter y values separated by spaces: ").split()))
x = np.array(x)
y = np.array(y)
plt.scatter(x, y)
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Scatter Plot of Input Data")
plt.show()
# Out:
# Enter x values separated by spaces: 1 2 3 4 5
# Enter y values separated by spaces: 1 2 3 4 5

# %%
import seaborn as sb
import numpy as np
import pandas as pd
a = np.random.randint(1, 10, size=10)
b = np.random.randint(1, 10, size=10)
df=pd.DataFrame({'a':a,'b':b})
sb.pairplot(df)

# %%
# !pip install joypy
import joypy
import numpy as np
import pandas as pd
l1=[[1,2,3],[1,2,3],[1,2,3]]
joypy.joyplot(l1)
# Out:
# ...
# (<Figure size 640x480 with 4 Axes>, [<Axes: >, <Axes: >, <Axes: >, <Axes: >])

# %%
# !pip install joypy
import joypy
import numpy as np
import pandas as pd
l1=[[1,2,3],[1,2,3],[1,2,3]]
joypy.joyplot(l1)
## or
n=int(input("enter no of lists"))
for i in range(n):
   l.append([int(x) for x in input("enter data").split()])
joypy.joyplot(l)
# Out:
# enter no of lists3
# enter data1 3 5
# enter data2 4 6
# enter data7 8 9
# (<Figure size 640x480 with 7 Axes>,
#  [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >])
